# %%
# 2) clone Tuan's resyslab (always required whenever starting a session in kaggle)
import os
if not os.path.exists('/kaggle/working/resyslab_utils'):
    # !git clone https://github.com/Azure2212/resyslab_utils.git
# %run /kaggle/working/resyslab_utils/resyslab_utils/clouds/cloud_setup.py
# Out:
# Cloning into 'resyslab_utils'...
# remote: Enumerating objects: 151, done.
# remote: Counting objects: 100% (151/151), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 151 (delta 55), reused 130 (delta 38), pack-reused 0 (from 0)
# Receiving objects: 100% (151/151), 30.63 KiB | 4.38 MiB/s, done.
# Resolving deltas: 100% (55/55), done.
# ---------------Tuan's resyslab library started!---------------

# %%
# 3) set authority right to push to github by using ssh
setup_github_config(private_key_path = '/kaggle/input/bayesnetworkcl/cogload_BN')
# Out:
# > Setup ssh github...
# Key name: cogload_BN
# Copy: /kaggle/input/bayesnetworkcl/cogload_BN --> ~/.ssh/cogload_BN
# setup github_config finished

# %%
# 4) pull code from github into kaggle using ssh private key setted up in previous step
clone_project_from_github(giturl = 'git@github.com:TyTy7023/CogLoad_BayesNetwork.git',
                          folder = '/kaggle/working/cogload', branch = 'getPDT')
# Out:
# Cloning into '/kaggle/working/cogload'...
# Warning: Permanently added '[ssh.github.com]:443' (ED25519) to the list of known hosts.
# remote: Enumerating objects: 1169, done.
# remote: Counting objects: 100% (189/189), done.
# remote: Compressing objects: 100% (159/159), done.
# remote: Total 1169 (delta 94), reused 72 (delta 28), pack-reused 980 (from 1)
# Receiving objects: 100% (1169/1169), 7.77 MiB | 4.68 MiB/s, done.
# Resolving deltas: 100% (652/652), done.

# %%
cd /kaggle/working/cogload
# Out:
# /kaggle/working/cogload

# %%
# %run -i /kaggle/working/cogload/main.py --GroupKFold 5
# Out:
# Data shapes:
# Labels (825, 21)
# Data (825, 107)
#   0%|          | 0/1000000 [00:00<?, ?it/s]
# Edges of DAG: [('temp_mean', 'temp_features'), ('temp_std', 'temp_features'), ('temp_max-min', 'temp_features'), ('temp_skew', 'temp_features'), ('temp_kurtosis', 'temp_features'), ('gsr_mean', 'gsr_features'), ('gsr_std', 'gsr_features'), ('gsr_max-min', 'gsr_features'), ('gsr_skew', 'gsr_features'), ('gsr_kurtosis', 'gsr_features'), ('rr_mean', 'rr_features'), ('rr_std', 'rr_features'), ('rr_max-min', 'rr_features'), ('rr_skew', 'rr_features'), ('rr_kurtosis', 'rr_features'), ('rr_diff2', 'rr_features'), ('HRV_Cd', 'rr_features'), ('HRV_AI', 'rr_features'), ('HRV_MedianNN', 'rr_features'), ('HRV_GI', 'rr_features'), ('HRV_CSI_Modified', 'rr_features'), ('HRV_CVNN', 'rr_features'), ('HRV_RMSSD', 'rr_features'), ('HRV_IALS', 'rr_features'), ('HRV_PAS', 'rr_features'), ('HRV_HFn', 'rr_features'), ('hr_mean', 'hr_features'), ('hr_std', 'hr_features'), ('hr_max-min', 'hr_features'), ('hr_skew', 'hr_features'), ('hr_kurtosis', 'hr_features'), ('hr_features', 'rr_features'), ('rr_features', 'gsr_features'), ('gsr_features', 'temp_features'), ('rr_features', 'Labels'), ('temp_features', 'Labels'), ('gsr_features', 'Labels')]
# len unique nodes:  36
# Shape train test val:  (504, 36) (128, 36)
#   0%|          | 0/100 [00:00<?, ?it/s]
# len unique nodes:  36
# Shape train test val:  (517, 36) (115, 36)
#   0%|          | 0/100 [00:00<?, ?it/s]
# len unique nodes:  36
# Shape train test val:  (518, 36) (114, 36)
#   0%|          | 0/100 [00:00<?, ?it/s]
# len unique nodes:  36
# Shape train test val:  (500, 36) (132, 36)
#   0%|          | 0/100 [00:00<?, ?it/s]
# len unique nodes:  36
# Shape train test val:  (489, 36) (143, 36)
#   0%|          | 0/100 [00:00<?, ?it/s]
# CPD của temp_mean:
# +--------------+---+
# | temp_mean(0) | 1 |
# +--------------+---+
#
# CPD của temp_features:
# +------------------+---------------------+------------------+
# | gsr_features     | gsr_features(0)     | gsr_features(1)  |
# +------------------+---------------------+------------------+
# | temp_kurtosis    | temp_kurtosis(0)    | temp_kurtosis(0) |
# +------------------+---------------------+------------------+
# | temp_max-min     | temp_max-min(0)     | temp_max-min(0)  |
# +------------------+---------------------+------------------+
# | temp_mean        | temp_mean(0)        | temp_mean(0)     |
# +------------------+---------------------+------------------+
# | temp_skew        | temp_skew(0)        | temp_skew(0)     |
# +------------------+---------------------+------------------+
# | temp_std         | temp_std(0)         | temp_std(0)      |
# +------------------+---------------------+------------------+
# | temp_features(0) | 0.5622489959839357  | 0.325            |
# +------------------+---------------------+------------------+
# | temp_features(1) | 0.43775100401606426 | 0.675            |
# +------------------+---------------------+------------------+
#
# CPD của temp_std:
# +-------------+---+
# | temp_std(0) | 1 |
# +-------------+---+
#
# CPD của temp_max-min:
# +-----------------+---+
# | temp_max-min(0) | 1 |
# +-----------------+---+
#
# CPD của temp_skew:
# +--------------+---+
# | temp_skew(0) | 1 |
# +--------------+---+
#
# CPD của temp_kurtosis:
# +------------------+---+
# | temp_kurtosis(0) | 1 |
# +------------------+---+
#
# CPD của gsr_mean:
# +-------------+---+
# | gsr_mean(0) | 1 |
# +-------------+---+
#
# CPD của gsr_features:
# +-----------------+--------------------+--------------------+
# | gsr_kurtosis    | gsr_kurtosis(0)    | gsr_kurtosis(0)    |
# +-----------------+--------------------+--------------------+
# | gsr_max-min     | gsr_max-min(0)     | gsr_max-min(0)     |
# +-----------------+--------------------+--------------------+
# | gsr_mean        | gsr_mean(0)        | gsr_mean(0)        |
# +-----------------+--------------------+--------------------+
# | gsr_skew        | gsr_skew(0)        | gsr_skew(0)        |
# +-----------------+--------------------+--------------------+
# | gsr_std         | gsr_std(0)         | gsr_std(0)         |
# +-----------------+--------------------+--------------------+
# | rr_features     | rr_features(0)     | rr_features(1)     |
# +-----------------+--------------------+--------------------+
# | gsr_features(0) | 0.5829596412556054 | 0.4473684210526316 |
# +-----------------+--------------------+--------------------+
# | gsr_features(1) | 0.4170403587443946 | 0.5526315789473685 |
# +-----------------+--------------------+--------------------+
#
# CPD của gsr_std:
# +------------+---+
# | gsr_std(0) | 1 |
# +------------+---+
#
# CPD của gsr_max-min:
# +----------------+---+
# | gsr_max-min(0) | 1 |
# +----------------+---+
#
# CPD của gsr_skew:
# +-------------+---+
# | gsr_skew(0) | 1 |
# +-------------+---+
#
# CPD của gsr_kurtosis:
# +-----------------+---+
# | gsr_kurtosis(0) | 1 |
# +-----------------+---+
#
# CPD của rr_mean:
# +------------+---+
# | rr_mean(0) | 1 |
# +------------+---+
#
# CPD của rr_features:
# +------------------+---------------------+---------------------+
# | HRV_AI           | HRV_AI(0)           | HRV_AI(0)           |
# +------------------+---------------------+---------------------+
# | HRV_CSI_Modified | HRV_CSI_Modified(0) | HRV_CSI_Modified(0) |
# +------------------+---------------------+---------------------+
# | HRV_CVNN         | HRV_CVNN(0)         | HRV_CVNN(0)         |
# +------------------+---------------------+---------------------+
# | HRV_Cd           | HRV_Cd(0)           | HRV_Cd(0)           |
# +------------------+---------------------+---------------------+
# | HRV_GI           | HRV_GI(0)           | HRV_GI(0)           |
# +------------------+---------------------+---------------------+
# | HRV_HFn          | HRV_HFn(0)          | HRV_HFn(0)          |
# +------------------+---------------------+---------------------+
# | HRV_IALS         | HRV_IALS(0)         | HRV_IALS(0)         |
# +------------------+---------------------+---------------------+
# | HRV_MedianNN     | HRV_MedianNN(0)     | HRV_MedianNN(0)     |
# +------------------+---------------------+---------------------+
# | HRV_PAS          | HRV_PAS(0)          | HRV_PAS(0)          |
# +------------------+---------------------+---------------------+
# | HRV_RMSSD        | HRV_RMSSD(0)        | HRV_RMSSD(0)        |
# +------------------+---------------------+---------------------+
# | hr_features      | hr_features(0)      | hr_features(1)      |
# +------------------+---------------------+---------------------+
# | rr_diff2         | rr_diff2(0)         | rr_diff2(0)         |
# +------------------+---------------------+---------------------+
# | rr_kurtosis      | rr_kurtosis(0)      | rr_kurtosis(0)      |
# +------------------+---------------------+---------------------+
# | rr_max-min       | rr_max-min(0)       | rr_max-min(0)       |
# +------------------+---------------------+---------------------+
# | rr_mean          | rr_mean(0)          | rr_mean(0)          |
# +------------------+---------------------+---------------------+
# | rr_skew          | rr_skew(0)          | rr_skew(0)          |
# +------------------+---------------------+---------------------+
# | rr_std           | rr_std(0)           | rr_std(0)           |
# +------------------+---------------------+---------------------+
# | rr_features(0)   | 0.416289592760181   | 0.48880597014925375 |
# +------------------+---------------------+---------------------+
# | rr_features(1)   | 0.583710407239819   | 0.5111940298507462  |
# +------------------+---------------------+---------------------+
#
# CPD của rr_std:
# +-----------+---+
# | rr_std(0) | 1 |
# +-----------+---+
#
# CPD của rr_max-min:
# +---------------+---+
# | rr_max-min(0) | 1 |
# +---------------+---+
#
# CPD của rr_skew:
# +------------+---+
# | rr_skew(0) | 1 |
# +------------+---+
#
# CPD của rr_kurtosis:
# +----------------+---+
# | rr_kurtosis(0) | 1 |
# +----------------+---+
#
# CPD của rr_diff2:
# +-------------+---+
# | rr_diff2(0) | 1 |
# +-------------+---+
#
# CPD của HRV_Cd:
# +-----------+---+
# | HRV_Cd(0) | 1 |
# +-----------+---+
#
# CPD của HRV_AI:
# +-----------+---+
# | HRV_AI(0) | 1 |
# +-----------+---+
#
# CPD của HRV_MedianNN:
# +-----------------+---+
# | HRV_MedianNN(0) | 1 |
# +-----------------+---+
#
# CPD của HRV_GI:
# +-----------+---+
# | HRV_GI(0) | 1 |
# +-----------+---+
#
# CPD của HRV_CSI_Modified:
# +---------------------+---+
# | HRV_CSI_Modified(0) | 1 |
# +---------------------+---+
#
# CPD của HRV_CVNN:
# +-------------+---+
# | HRV_CVNN(0) | 1 |
# +-------------+---+
#
# CPD của HRV_RMSSD:
# +--------------+---+
# | HRV_RMSSD(0) | 1 |
# +--------------+---+
#
# CPD của HRV_IALS:
# +-------------+---+
# | HRV_IALS(0) | 1 |
# +-------------+---+
#
# CPD của HRV_PAS:
# +------------+---+
# | HRV_PAS(0) | 1 |
# +------------+---+
#
# CPD của HRV_HFn:
# +------------+---+
# | HRV_HFn(0) | 1 |
# +------------+---+
#
# CPD của hr_mean:
# +------------+---+
# | hr_mean(0) | 1 |
# +------------+---+
#
# CPD của hr_features:
# +----------------+---------------------+
# | hr_kurtosis    | hr_kurtosis(0)      |
# +----------------+---------------------+
# | hr_max-min     | hr_max-min(0)       |
# +----------------+---------------------+
# | hr_mean        | hr_mean(0)          |
# +----------------+---------------------+
# | hr_skew        | hr_skew(0)          |
# +----------------+---------------------+
# | hr_std         | hr_std(0)           |
# +----------------+---------------------+
# | hr_features(0) | 0.45194274028629855 |
# +----------------+---------------------+
# | hr_features(1) | 0.5480572597137015  |
# +----------------+---------------------+
#
# CPD của hr_std:
# +-----------+---+
# | hr_std(0) | 1 |
# +-----------+---+
#
# CPD của hr_max-min:
# +---------------+---+
# | hr_max-min(0) | 1 |
# +---------------+---+
#
# CPD của hr_skew:
# +------------+---+
# | hr_skew(0) | 1 |
# +------------+---+
#
# CPD của hr_kurtosis:
# +----------------+---+
# | hr_kurtosis(0) | 1 |
# +----------------+---+
#
# CPD của Labels:
# +---------------+--------------------+-----+------------------+---------------------+
# | gsr_features  | gsr_features(0)    | ... | gsr_features(1)  | gsr_features(1)     |
# +---------------+--------------------+-----+------------------+---------------------+
# | rr_features   | rr_features(0)     | ... | rr_features(1)   | rr_features(1)      |
# +---------------+--------------------+-----+------------------+---------------------+
# | temp_features | temp_features(0)   | ... | temp_features(0) | temp_features(1)    |
# +---------------+--------------------+-----+------------------+---------------------+
# | Labels(0)     | 0.3194444444444444 | ... | 0.62             | 0.6185567010309279  |
# +---------------+--------------------+-----+------------------+---------------------+
# | Labels(1)     | 0.6805555555555556 | ... | 0.38             | 0.38144329896907214 |
# +---------------+--------------------+-----+------------------+---------------------+
